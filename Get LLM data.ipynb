# %% [markdown]
# #### Dictionary coverage

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from scipy import stats
import statistics
from matplotlib.patches import FancyArrow
import json

plt.rcParams['figure.dpi'] = 900

# 将X/Y轴的刻度线方向设置向内
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# 设置字体
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Microsoft Yahei'

# 设置公式字体
config = {
    "mathtext.fontset": 'stix',
}
rcParams.update(config)
colors = ['#3a3a8c', '#7daae2', '#fae084', '#f47044', '#cf3d3c', '#a5514e']


# 搜索词组的句子
# def search_phrase(filename, phrase):
#     local_data = []
#     text = []
#     with open('./data/' + filename, 'r', encoding='utf-8') as file:
#         local_data = json.load(file)
#     for ele in local_data:
#         if phrase in ele['phrase']:
#             text.append(ele['text'].strip())
#     return text
    

def appear_times_for_single(data, phrase):
    times = 0
    for i,ele in enumerate(data):
        if phrase in list(ele['phrase'].keys()):
            times += ele['phrase'][phrase]
    return times    


def count_bins(number):
    n_string = '{:.15f}'.format(number)
    decimal_part = str(n_string).split('.')[1]  # 将小数部分转换为字符串并分割
    count = 0
    for digit in decimal_part:
        if digit == '0':
            count += 1
        else:
            break  # 遇到第一个非零数字就停止计数
    return count + 1


# Michel 2007 计算频区间的中心值
def get_center_value(freqs):
    maxi = np.log10(max(freqs))
    minu = np.log10(min(freqs))
    center = (maxi + minu) / 2  # logarithmic mean 对数均值
    return 10**center

# %% [markdown]
# ##### 选择数据集版本

# %%
filename = 'en_data_final_1.json'

# %% [markdown]
# ##### 加载Json到内存

# %%
local_data = []
with open('./data/'+filename, 'r', encoding='utf-8') as file:
    local_data = json.load(file)
print(len(local_data))
print(local_data[0])

# 统计词组类型
phrases = []

for ele in local_data:
    text = ele['text']
    phrase_list = ele['phrase']
    for p in phrase_list:
        phrases.append(p)

from collections import Counter

latin_phrases = []
apper_times = {}
# 使用Counter统计元素个数
element_counts = Counter(phrases)
# 按照出现次数降序排序
sorted_counts = sorted(element_counts.items(), key=lambda x: x[1], reverse=True)
# 输出排序结果
for element, count in sorted_counts:
    print(f"{element}: {count}")
    latin_phrases.append(element)
    apper_times[element] = count

# print(latin_phrases)

# 保存数据集中出现的拉丁词组
# with open('./data/data readability/latin phrases.txt', 'w', encoding='utf-8') as file:
#     for pha in latin_phrases:
#         file.write(pha + '\n')
# file.close()

# %%
# 查找语句
def search_phrase(phrase, data):
    results = []
    for ele in data:
        # if len(ele['phrase'].keys()) > 1:
        #     print(ele['phrase'])
        if phrase in ele['phrase'].keys():
            results.append(ele)
    return results
        
        
pha = 'alter ego'
len(search_phrase(pha, local_data))
# Out:
# 4932

# %% [markdown]
# ##### 获取只有一个拉丁词组的语句

# %%
selected_phrases = []
with open('./data/data readability/latin phrases.txt', 'r', encoding='utf-8') as file:
    contents = file.readlines()
    print(len(contents))
    for ele in contents:
        selected_phrases.append(ele.strip())
# print(selected_phrases)

# 将语句的数量限制在100条以内，一个词组对应的语句不超过100条
phrase_text_dict = {}
for i, pha in enumerate(selected_phrases):
    # if i+1 > 1:
    #     break
    # print(i+1, pha)
    ele_list = []
    for ele in search_phrase(pha, local_data):
        # print(ele)
        # 对于{'de facto': 12, 'de jure': 1}，跳过包含多个词组的语句
        # {'ex vivo': 2} 一句话中包含多个相同词组的情况，跳过
        if len(ele['phrase'].keys())==1 and  ele['phrase'][pha]==1 and len(ele['text'])==1:
            ele_list.append(ele)
            # print(type(ele), ele)
    # print(len(ele_list))
    # 获取词组和对应的语句
    text_list = []
    for j, pha_dict in enumerate(ele_list):
        # if j > 2:
        #     break
        # print(j+1, pha_dict)
        try:
            # 将string文本 转换成 dict
            text_string = str(pha_dict['text'])
            text_dict = json.loads(text_string.replace("'", "\""))

            text = text_dict[pha].strip()
            if pha not in text:
                continue
            text_list.append(text)
            # print(pha, text)
        # 按照上面的 string-->dict 有一部分的语句可能会转换失败
        # 对于出现错误的语句，不用处理，直接跳过
        except Exception as e:
            continue
    if len(text_list) != 0:
        phrase_text_dict[pha] = text_list
        print(i+1, pha, len(text_list))

# print(len(phrase_text_dict['status quo']))
# Out:
# 760
# 1 status quo 21191
# 2 de facto 15196
# 3 per capita 12715
# 4 vice versa 8245
# 5 per se 6709
# 6 alma mater 7437
# 7 pros and cons 7038
# 8 per annum 6466
# 9 ad hoc 5664
# 10 bona fide 4375
# 11 in fine 4656
# 12 in retrospect 3438
# 13 alter ego 2549
# 14 modus operandi 2691
# 15 pro bono 2629
# 16 in vitro 1783
# 17 a cappella 1899
# 18 in absentia 2051
# 19 quid pro quo 1717
# 20 et cetera 1088
# 21 prima facie 1417
# 22 in situ 1826
# 23 pro forma 1168
# 24 inter alia 1268
# 25 habeas corpus 1225
# 26 post mortem 1439
# 27 mea culpa 1121
# 28 in vivo 575
# 29 magnum opus 930
# 30 per diem 782
# 31 ad hominem 685
# 32 ad nauseam 833
# 33 persona non grata 706
# 34 pro tem 745
# 35 in utero 696
# 36 in camera 577
# 37 a priori 530
# 38 spina bifida 556
# 39 de jure 219
# 40 ad infinitum 544
# 41 pro rata 502
# 42 sine qua non 498
# 43 suo motu 489
# 44 in pace 452
# 45 curriculum vitae 512
# 46 pro tempore 410
# 47 ex parte 328
# 48 amicus curiae 349
# 49 de novo 282
# 50 terra firma 387
# 51 aurora borealis 312
# 52 sui generis 341
# 53 non sequitur 300
# 54 ipso facto 300
# 55 ad valorem 264
# 56 casus belli 303
# 57 homo sapiens 282
# 59 ex post 52
# 60 deus ex machina 260
# 61 ex officio 278
# 62 in extremis 232
# 63 in toto 234
# 64 in memoriam 232
# 65 modus vivendi 203
# 66 de minimis 155
# 68 caveat emptor 169
# 69 ad litem 163
# 70 sine die 175
# 71 sub judice 147
# 72 ultra vires 139
# 73 post hoc 129
# 74 sanctum sanctorum 162
# 75 rigor mortis 156
# 76 tabula rasa 143
# 77 juris doctor 166
# 78 ab initio 135
# 79 dramatis personae 149
# 80 locus standi 132
# 81 annus horribilis 124
# 82 in re 140
# 83 mala fide 116
# 84 via media 142
# 85 pro se 115
# 86 ex vivo 50
# 87 stare decisis 101
# 88 corpus callosum 97
# 89 ad absurdum 17
# 90 ex ante 82
# 91 ex gratia 111
# 92 terra incognita 118
# 93 carpe diem 91
# 94 memento mori 100
# 95 camera obscura 86
# 96 in loco 26
# 97 gluteus maximus 108
# 98 ne plus ultra 110
# 99 mens rea 70
# 100 ex nihilo 85
# 102 ad interim 88
# 103 quo warranto 79
# 104 pari passu 65
# 105 in silico 44
# 106 honoris causa 83
# 107 substantia nigra 52
# 108 vox populi 65
# 109 in flagrante 31
# 110 motu proprio 63
# 111 sub rosa 72
# 113 per curiam 60
# 114 terra nullius 39
# 115 ceteris paribus 59
# 116 nolle prosequi 54
# 117 inter partes 58
# 118 primus inter pares 68
# 119 delirium tremens 66
# 120 annus mirabilis 54
# 121 mutatis mutandis 40
# 122 a fortiori 41
# 123 ex cathedra 36
# 124 e pluribus unum 31
# 125 in dubio 31
# 126 aurora australis 9
# 127 ad limina 32
# 128 dura mater 40
# 129 post partum 42
# 130 in medias res 45
# 131 flagrante delicto 2
# 132 a posteriori 22
# 134 jus soli 20
# 135 nolo contendere 29
# 136 foramen ovale 30
# 137 viva voce 40
# 138 cui bono 27
# 139 in limine 27
# 140 propter hoc 3
# 141 sola scriptura 21
# 142 mirabile dictu 34
# 143 locum tenens 28
# 144 genius loci 22
# 145 compos mentis 23
# 146 jus in bello 11
# 147 in excelsis 23
# 148 foramen magnum 28
# 150 ante bellum 15
# 151 jus ad bellum 9
# 152 in rem 22
# 153 cura personalis 26
# 154 ad libitum 22
# 155 pater familias 22
# 156 sola fide 17
# 157 per mille 23
# 158 jus sanguinis 2
# 159 et alia 23
# 160 tu quoque 12
# 161 res judicata 12
# 162 sede vacante 18
# 163 sua sponte 14
# 164 rara avis 20
# 165 inter vivos 23
# 166 in se 10
# 167 per centum 11
# 168 cor pulmonale 22
# 169 in specie 13
# 170 inter se 12
# 171 locus classicus 14
# 172 pro hac vice 20
# 173 res publica 15
# 174 obiter dicta 14
# 175 erga omnes 14
# 176 homo erectus 13
# 177 magna carta 9
# 178 in extenso 12
# 179 actus reus 3
# 180 globus pallidus 7
# 181 materia medica 11
# 182 pacta sunt servanda 7
# 183 fons et origo 13
# 184 corpus luteum 11
# 185 pro patria 8
# 186 corpus delicti 13
# 187 summum bonum 13
# 188 post factum 13
# 190 panem et circenses 11
# 191 ars technica 13
# 192 ex facie 8
# 193 parens patriae 13
# 194 vade mecum 6
# 195 nota bene 13
# 196 ultima ratio 9
# 197 ex situ 5
# 198 sola gratia 4
# 199 in vino veritas 6
# 200 de fide 7
# 201 in terrorem 10
# 202 ars poetica 10
# 203 lignum vitae 12
# 204 nihil obstat 9
# 205 id est 7
# 206 coitus interruptus 8
# 207 ad idem 8
# 208 damnatio memoriae 8
# 209 aqua regia 9
# 210 ipse dixit 9
# 211 respondeat superior 7
# 212 mea maxima culpa 6
# 213 ex libris 8
# 214 anno domini 6
# 215 primum non nocere 8
# 216 sensu stricto 8
# 218 in pectore 7
# 219 in vacuo 10
# 220 urbi et orbi 8
# 221 ora et labora 10
# 222 res ipsa loquitur 6
# 223 pontifex maximus 9
# 224 perpetuum mobile 8
# 225 ex hypothesi 3
# 226 modus ponens 4
# 227 pro tanto 6
# 228 numerus clausus 5
# 229 quo vadis 7
# 230 audi alteram partem 6
# 231 obiter dictum 4
# 232 ad astra 10
# 233 de re 1
# 234 semper fidelis 7
# 235 dementia praecox 3
# 236 aqua vitae 4
# 237 ratio decidendi 8
# 238 per incuriam 4
# 239 quantum meruit 8
# 240 camera lucida 5
# 241 sub specie aeternitatis 7
# 242 non plus ultra 4
# 243 lex talionis 6
# 244 cursus honorum 5
# 245 ante mortem 5
# 246 horror vacui 7
# 247 a latere 3
# 248 hostis humani generis 6
# 249 felix culpa 2
# 250 cantus firmus 8
# 252 divide et impera 3
# 253 fiat lux 4
# 254 contra mundum 4
# 255 in salvo 8
# 256 mens sana in corpore sano 6
# 257 rus in urbe 9
# 258 sub silentio 6
# 259 modus tollens 2
# 260 ars moriendi 6
# 261 persona grata 4
# 262 sui iuris 6
# 263 eo ipso 5
# 265 uti possidetis 4
# 266 mare nostrum 7
# 267 pia mater 6
# 269 mater dolorosa 7
# 270 primum mobile 6
# 271 malum prohibitum 2
# 272 ex opere operato 3
# 273 in partibus 3
# 274 manu militari 5
# 275 ex tempore 5
# 276 opus magnum 6
# 277 in nomine 3
# 278 petitio principii 2
# 279 ex more 6
# 281 via dolorosa 6
# 282 ad usum 2
# 283 non licet 4
# 284 in pari delicto 3
# 285 sensu lato 2
# 286 ars longa 2
# 287 tertium quid 3
# 288 ex utero 3
# 289 semper reformanda 4
# 290 quod erat demonstrandum 4
# 291 amor fati 2
# 292 novus ordo seclorum 1
# 293 intra vires 3
# 294 in facie 1
# 295 ratione personae 2
# 296 studium generale 2
# 297 circus maximus 6
# 298 per mensem 2
# 300 advocatus diaboli 5
# 301 bellum omnium contra omnes 3
# 302 ex aequo 4
# 303 ad referendum 2
# 304 functus officio 2
# 305 vita brevis 2
# 306 ante meridiem 1
# 307 per impossibile 2
# 308 ad honorem 5
# 309 corpus juris 3
# 310 homo sacer 2
# 311 in saecula saeculorum 1
# 312 in capite 4
# 313 editio princeps 3
# 314 in solidum 4
# 316 homo floresiensis 3
# 317 restitutio in integrum 3
# 318 schola cantorum 1
# 319 ad vitam 3
# 320 pecunia non olet 3
# 321 in quarto 1
# 322 in personam 3
# 323 in actu 1
# 324 nil desperandum 3
# 325 nomen est omen 3
# 326 festina lente 3
# 328 hortus conclusus 2
# 329 post bellum 3
# 331 arcus senilis 3
# 333 homo homini lupus 4
# 334 ora pro nobis 3
# 335 jus gentium 1
# 336 lex loci 1
# 337 ab ovo 3
# 338 de profundis 1
# 339 opus dei 3
# 341 ad finem 3
# 343 ad fontes 2
# 344 ipsissima verba 2
# 345 custos morum 2
# 346 sic transit gloria mundi 2
# 348 ignis fatuus 3
# 349 apologia pro vita sua 3
# 350 noli me tangere 3
# 351 deus vult 3
# 352 in forma pauperis 2
# 353 ne bis in idem 2
# 354 terra nova 1
# 356 homo ludens 1
# 359 vel non 3
# 362 non placet 2
# 363 textus receptus 2
# 364 in spe 3
# 365 opera omnia 2
# 366 in usu 3
# 367 in casu 3
# 368 lux et veritas 2
# 369 disjecta membra 3
# 370 incertae sedis 4
# 371 doli incapax 1
# 372 sensus plenior 3
# 373 expressio unius est exclusio alterius 1
# 374 pons asinorum 2
# 376 credo ut intelligam 1
# 377 a mari usque ad mare 1
# 378 fluctuat nec mergitur 1
# 379 in aeternum 2
# 380 caveat venditor 1
# 381 nolens volens 1
# 382 onus probandi 1
# 384 ex voto 1
# 385 extra ecclesiam nulla salus 1
# 386 contra proferentem 3
# 388 pendente lite 3
# 389 omnium gatherum 2
# 391 contradictio in adjecto 2
# 392 inter alios 1
# 393 dies irae 4
# 394 pro domo 4
# 395 translatio imperii 4
# 396 spiritus rector 1
# 397 in rebus 1
# 398 de mortuis nil nisi bonum 3
# 399 pro et contra 1
# 400 nemo dat quod non habet 1
# 401 res cogitans 1
# 402 mare liberum 3
# 403 dux bellorum 3
# 404 felo de se 1
# 405 salus populi suprema lex 2
# 406 contra bonos mores 2
# 407 nulla poena sine lege 1
# 408 ne temere 1
# 410 totus tuus 1
# 411 et passim 2
# 412 in natura 1
# 413 facile princeps 3
# 414 sursum corda 2
# 416 per os 1
# 417 ne cede malis 1
# 419 semper paratus 1
# 422 fides quaerens intellectum 2
# 423 ab aeterno 1
# 424 ubi sunt 2
# 425 a contrario 1
# 428 ius cogens 2
# 429 opus sectile 2
# 431 in esse 3
# 432 contra legem 2
# 433 quis custodiet ipsos custodes 1
# 437 coram deo 2
# 439 non obstante 1
# 440 animal rationale 1
# 441 spiritus mundi 2
# 443 ignoratio elenchi 1
# 446 homo oeconomicus 1
# 448 arcana imperii 3
# 449 suum cuique 2
# 451 nullius in verba 2
# 452 papaver somniferum 3
# 454 in foro 1
# 455 punctum saliens 2
# 456 sic semper tyrannis 1
# 457 vide supra 2
# 458 nisi prius 1
# 459 in ovo 1
# 460 credo quia absurdum 1
# 461 locus poenitentiae 1
# 462 nemo iudex in causa sua 2
# 463 gradatim ferociter 1
# 464 homo faber 2
# 465 ad patres 1
# 467 deo gratias 2
# 468 ad absurdem 1
# 469 de plano 1
# 471 ab extra 2
# 472 conditio humana 1
# 476 in abstracto 1
# 481 pars pro toto 1
# 483 res nullius 1
# 484 res gestae 1
# 485 fidei defensor 2
# 486 novus homo 2
# 488 ius primae noctis 2
# 489 sol invictus 2
# 490 opus anglicanum 2
# 491 et hoc genus omne 2
# 492 rerum novarum 2
# 493 ad acta 1
# 494 nemo judex in causa sua 2
# 495 pleno jure 1
# 498 in futuro 1
# 503 in perpetuum 1
# 504 ex opere operantis 1
# 506 vox humana 2
# 507 de te fabula narratur 1
# 508 jus primae noctis 1
# 509 pax romana 1
# 511 ex injuria jus non oritur 1
# 512 in posse 2
# 516 opus est 1
# 517 in globo 1
# 521 stupor mundi 1
# 522 magister artium 1
# 524 risus sardonicus 1
# 525 mare clausum 1
# 526 pluralis majestatis 1
# 529 qui bono 1
# 531 factum est 2
# 533 vena amoris 2
# 535 pro mille 2
# 536 ex abundanti cautela 1
# 538 fiat voluntas tua 1
# 540 fac simile 1
# 543 locus delicti 1
# 544 damnatio ad bestias 1
# 545 in nuce 1
# 552 sidere mens eadem mutato 1
# 556 particeps criminis 1
# 558 primum movens 1
# 559 extra moenia 1
# 560 nosce te ipsum 1
# 561 loci communes 1
# 572 mundus vult decipi 1
# 576 pro re nata 1
# 577 proxima centauri 1
# 578 ultima thule 1
# 580 vide infra 1
# 581 age quod agis 1
# 588 ab urbe condita 1
# 592 nulli secundus 1
# 594 semper vigilans 1
# 595 obtorto collo 1
# 596 helluo librorum 1
# 605 audiatur et altera pars 1
# 606 pax vobiscum 1
# 608 dura lex sed lex 1
# 610 ad alta 1
# 613 etsi deus non daretur 1
# 614 philosophiae doctor 1
# 617 hic et nunc 1
# 625 ad unum 1
# 633 a minima 1
# 642 mortis causa 1
# 644 vera causa 1
# 647 secundum artem 1
# 652 vivat rex 1
# 664 in ictu oculi 1
# 665 ex solo ad solem 1
# 666 odi et amo 1
# 667 nunc dimittis 1
# 675 ter in die 1
# 680 odium theologicum 1
# 688 tertium non datur 1
# 690 vinculum juris 1
# 691 pollice verso 1
# 692 damnum absque injuria 1
# 694 non vi sed saepe cadendo 1
# 697 mos maiorum 1
# 701 e silentio 1
# 703 venia legendi 1
# 706 utraque unum 1
# 707 lapsus linguae 1
# 711 ars antiqua 1
# 714 jure humano 1
# 716 utile dulci 1
# 719 laudator temporis acti 1
# 721 virgo intacta 1
# 722 radix malorum est cupiditas 1
# 724 lapsus calami 1
# 725 ignorantia legis neminem excusat 1
# 728 mirabile visu 1
# 732 memento vivere 1
# 736 extra muros 1
# 744 vis major 1
# 745 aqua pura 1
# 746 varia lectio 1
# 750 decus et tutamen 1
# 751 esse quam videri 1
# 758 habent sua fata libelli 1
# 759 ius gentium 1

# %%
import random


# 将排序好的列表分成 number 等份， 再获取中间的元素
def get_middle_values(sorted_list, number):
    chunk_size = len(sorted_list) // number
    # 从每份中选取中间的元素
    middle_elements = []
    for i in range(number):
        start_index = i * chunk_size
        end_index = start_index + chunk_size
        middle_index = (start_index + end_index) // 2
        middle_elements.append(sorted_list[middle_index])
    return middle_elements


# 词组和对应的语句列表
using_dict = {}
# 获取语料
number = 0
for i, (pha, texts) in enumerate(phrase_text_dict.items()):
    # if (i+1) > 1:
    #     break
    # print(pha)
    # 如果语句的数量超过 50条，从中随机选取 50条作为实验对象
    selected_texts = []
    if len(texts) >= 50:
        # 按照文本字符数量排序，均匀选取
        sorted_texts = sorted(texts, key=lambda x: len(x))
        # selected_texts = random.sample(texts, 10)
        selected_texts = get_middle_values(sorted_texts, 50)
    else:
        selected_texts = texts
    # print(pha, len(selected_texts))
    number += len(selected_texts)
    using_dict[pha] = selected_texts
    
print('词组数量:', len(phrase_text_dict))
print('语句数量:', number)

# save dict, using LLMs generate
with open('./data/llm/LE-dataset v1.2.json', 'w') as file:
    json.dump(using_dict, file, indent=4)
file.close()
# Out:
# 词组数量: 527
# 语句数量: 8003

# %%
import json

def compare_json_files(file1_path, file2_path):
    # 读取第一个 JSON 文件并加载为字典
    with open(file1_path, 'r') as file1:
        json_data1 = json.load(file1)

    # 读取第二个 JSON 文件并加载为字典
    with open(file2_path, 'r') as file2:
        json_data2 = json.load(file2)

    # 比较两个字典是否相同
    return json_data1 == json_data2

# 两个 JSON 文件的路径
file1_path = './data/llm/LE-dataset v1.0.json'
file2_path = './data/llm/LE-dataset v1.1.json'

# 比较两个 JSON 文件是否相同
result = compare_json_files(file1_path, file2_path)

if result:
    print("两个 JSON 文件相同")
else:
    print("两个 JSON 文件不同")
# Out:
# 两个 JSON 文件相同
